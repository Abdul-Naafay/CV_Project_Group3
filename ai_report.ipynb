# %% [markdown]
# AI REPORT
#
# phase1
# - asked gpt for a plan overall to get the steps. Manual was a bit confusing in this
#
# - preprocessing was AI -> i asked it to resize and grayscale the image (code is ai)
#
# - used ai to write code for visualising the key points between img i and i+1
#
#
#
# phase2
# -  used ai to extract the key info (focal length and cx,cy) from the exif data of iphone to calculate the intrinsic matrix
#
# - ai told me we cant use the oirignal f and cx,cy for K -> we need to resize it as we rescaled the images
#
# - same code as phase 1 for visualisations (also ai)
#
# - asked gpt about the parameters to cv2.findEssentialMat() as i didnt know how the function needs to be called
#
# - the ravel function was ai i didnt know why we do that
#
# - i knew how the matrices will look (p1 and p2) but asked gpt to write code (hstack kya karta hai bhae????)
#
# - the inputs to the triangulatePoints functuions were from gpt too (didnt know how what it takes)
#
# - saving pt cloud by ai
#
# - used ai to calculate the reproj error
#
# - used ai for visualisations
